# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned data
df = pd.read_csv('/data/processed/final.csv')

# Correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')pip uninstall scikit-learn imbalanced-learn -y
pip install scikit-learn==1.5.2 imbalanced-learn

plt.show()

# Feature distributions
df.select_dtypes(include='number').hist(bins=15, figsize=(15, 10))
plt.show()

# Target distribution (GII VALUE)
plt.figure(figsize=(8, 6))
sns.histplot(df['GII VALUE'], kde=True, color='blue')
plt.title('Distribution of GII VALUE')
plt.show()

# Missing values heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()
